# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import math
import random

# %%
sns.set_theme(style='darkgrid', font_scale=1.2)
sns.set_style({'axes.grid': True, 'grid.color': 'gray'})
custom_palette = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']
sns.set_palette(custom_palette)

# %%
def random_subset(arr1, arr2, subset_size):
    """
    Takes two arrays and returns random subsets of the two
    
    Arguments:
    arr (1darray)    : Input array
    subset_size (int): Desired size of random subset
    
    Returns:
    random_subset (1darray): Random subset of arr
    """
    if subset_size > len(arr1):
        raise ValueError("Subset size cannot be greater than array length")
    
    random_indices = random.sample(range(len(arr1)), subset_size)
    
    # need to use same random indices to ensure feature target mapping is consistent
    random_subset_1 = [arr1[index] for index in random_indices]
    random_subset_2 = [arr2[index] for index in random_indices]
    
    return random_subset_1, random_subset_2

# %% [markdown]
# ## 1.0 Problem Statement
# We're interested in the relationship between water salinity "Salnty" and water temperature "T_degC." We are want to know whether we can predict the temperature of water based on its salinity.
#
#
# Our initial approach is going to be using simple linear regression via gradient descent following the machine learning specialization course by deeplearning.ai. This is just to get a better understanding of how the technique functions and how it performs against other implementations. We will then build a polynomial model.
#
# ## 1.1 Data Understanding
# Consider
# - Business/domain understanding. Why are things distributed this way. Look into data more wholistically
# - How many samples do we really need? What proportion should we hold out for testing and for validation?
# - Feature distribution
# - Normalization
# - Summary statistics

# %%
df = pd.read_csv("tempsal.csv")
df.shape
# Out:
# (864863, 2)

# %%
df.head()
# Out:
#    T_degC  Salnty
# 0   10.50  33.440
# 1   10.46  33.440
# 2   10.46  33.437
# 3   10.45  33.420
# 4   10.45  33.421

# %%
df.describe()
# Out:
#               T_degC         Salnty
# count  853900.000000  817509.000000
# mean       10.799677      33.840350
# std         4.243825       0.461843
# min         1.440000      28.431000
# 25%         7.680000      33.488000
# 50%        10.060000      33.863000
# 75%        13.880000      34.196900
# max        31.140000      37.034000

# %%
df.isna().sum()
# Out:
# T_degC    10963
# Salnty    47354
# dtype: int64

# %%
df.dropna(axis = 0, inplace=True)
X = np.array(df["Salnty"])
y = np.array(df["T_degC"])
df.isna().sum()
# Out:
# T_degC    0
# Salnty    0
# dtype: int64

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14,4))
sns.histplot(x=df.Salnty, ax=axes[0])
axes[0].set_title('Salinity Distribution')

sns.histplot(x=df.T_degC, ax=axes[1])
axes[1].set_title('Temperature Distribution (C)')
                     
plt.tight_layout()
plt.show()

# %% [markdown]
# We have too many data points for a clear scatter graph which could mean a misleading visualization. So instead of
# plotting all data points, we will plot a four random subsets (n=2000) to get an idea of the relationship between temperature and salinity

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(14,8))
X_2k_1, y_2k_1 = random_subset(X, y, 2000); X_2k_2, y_2k_2 = random_subset(X, y, 2000) 
X_2k_3, y_2k_3 = random_subset(X, y, 2000); X_2k_4, y_2k_4 = random_subset(X, y, 2000); 
axes[0, 0].scatter(x= X_2k_1, y= y_2k_1)
axes[0, 1].scatter(x = X_2k_2, y = y_2k_2, c='#9467bd')
axes[1, 0].scatter(x = X_2k_3, y = y_2k_3, c='#fdae6b')
axes[1, 1].scatter(x = X_2k_4, y = y_2k_4, c='#c49c94')
plt.xlabel("Salinity")
plt.ylabel("Temp degC")
plt.title("Water salinity against temperature")
plt.tight_layout()
plt.show()

# %% [markdown]
# One the face of it a linear model may be adequate though a polynomial model would help capture the nuance below ~32.5 degrees and after ~34.7. The choice of model will affect our choice of sample size for training the model as 80,000 data points is overkill for a simple linear model with only one feature input.
#
# Either way we can benefit by holding out more testing and validation data. In the interest of using most of the data we will go for a 50:25:25 split, 50% training, 25% testing, 25% validation. The validation data will ensure we don't train the model to the testing set when we approach with different methods

# %% [markdown]
# ## 1.2 Data Preparation

# %%
# even with one feature it might be worth normalizing if there's a significant difference in range
print(f"Min water salinity is: {df['Salnty'].min()} and max is: {df['Salnty'].max()}")
print(f"Min water temp is: {df['T_degC'].min()} and max is: {df['T_degC'].max()}")
# Out:
# Min water salinity is: 28.431 and max is: 37.034
# Min water temp is: 1.44 and max is: 31.14

# %% [markdown]
# ## 2.0 Modelling
# ### 2.1 Functions for Linear Regression

# %%
def compute_cost(X, y, w, b):
    """
    Computes the cost function for linear regression using 
    the whole batch
    
    Args:
        X (ndarray (m,)): Data, m examples
        y (ndarray (m,)): target values
        w,b (scalar)    : model parameters
        
        Returns cost of using w, b as parameters for our linear regression model
        
    """
    m = X.shape[0]
    
    cost_sum = 0 
    for i in range(m):
        f_wb = w * X[i] + b # linear model
        cost = (f_wb - y[i]) ** 2 # difference between the predicted values and the actual 
        cost_sum += cost # summing over m examples
    total_cost = (1 / (2 * m)) * cost_sum
    
    return total_cost

# %%
def compute_gradient(X, y, w, b):
    """
    Computes the gradient for linear regression
    
    Args:
        X (ndarray (m,)): Data, m examples
        y (ndarray (m,)): target values 
        w,b (scalar)    : model parameters
    Returns
        dj_dw (scalar): partial derivative of cost w.r.t. w
        dj_db (scalar): partial derivative of cost w.r.t. b
    """
    
    m = X.shape[0]
    dj_dw = 0
    dj_db = 0
    
    # summing from i = 0 to m - 1 the sum term in the partial derivatives
    for i in range(m):
        f_wb = w * X[i] + b  # Linear model 
        dj_dw_i = (f_wb - y[i]) * X[i] 
        dj_db_i = f_wb - y[i]
        dj_db += dj_db_i
        dj_dw += dj_dw_i
    dj_dw = dj_dw / m 
    dj_db = dj_db / m 
    
    return dj_dw, dj_db

# %%
def gradient_descent(X, y, w_in, b_in, alpha, num_iters, cost_function, gradient_function):
    """
    Performs gradient descent to fit linear model. Updates w,b by taking 
    num_iters gradient steps with learning rate alpha (step size)
    
    Args:
        X (ndarray (m,))   : Data, m examples
        y (ndarray (m,))   : target values 
        w_in, b_in (scalar): initial values of model parameters
        alpha (float)      : Learning rate
        num_iters (int)    : number of iterations for gradient descent
        cost_function      : function to produce cost of current model
        gradient_function  : function to produce gradient of cost w.r.t. parameters
        
    Returns:
        w (scalar): Updated value of parameter after running gradient descent
        b (scalar): Updated value of parameter after running gradient descent
        """
    b = b_in
    w = w_in 
    J = [] # tracking the cost every 100 iterations to study convergence
    
    for i in range(num_iters):
        #calculate the gradient and update the parameters using gradient_function
        dj_dw, dj_db =  compute_gradient(X, y, w, b)
        
        # Update parameters using our w = w - alpha*dj_dw etc.
        b = b - alpha * dj_db
        w = w - alpha * dj_dw 
        
        if i % 100 == 0 and i != 0:
            J.append(compute_cost(X_train, y_train, w, b))
    return w, b, J

# %% [markdown]
# ### 2.2 Linear Model

# %% [markdown]
# We'll estimate our initial w and b values based off our understanding of the data so far. A linear model would likely be more effective with a negative slope (negative w).

# %%
plt.scatter(x = "Salnty", y = "T_degC", data = df)
y1 = -0.6*X + 35
plt.plot(X, y1, '-r', label='y=wx+b')
plt.xlabel("Salinity")
plt.ylabel("Temp degC")
plt.title("Water salinity against temperature")
plt.show()

# %%
# Initial estimated parameters
w_init = -0.6
b_init = 35
# Calculate an 50/50 test-validation/train split
train_size = round(X.shape[0]*0.5)
X_train = X[:train_size]
y_train = y[:train_size]
iteration = 1000
tmp_alpha = 1.0e-4
w_final, b_final, J = gradient_descent(X_train, y_train, w_init, b_init, tmp_alpha, iteration, compute_cost, compute_gradient)
print(f"(w,b) found by gradient descent: ({w_final:8.4f},{b_final:8.4f})")
# Out:
# (w,b) found by gradient descent: ( -0.7160, 34.9987)

# %%
# Something is wrong with how J is tracking the cost function, fix this
#iterations = [i*100 for i in range(len(J))]

#sns.lineplot(x=iterations, y=J, color='blue')

#plt.xlabel("Iterations")
#plt.ylabel("Cost function")
#plt.title("Cost function over gradient descent")
#plt.show()

# %%
plt.scatter(x = "Salnty", y = "T_degC", data = df)
y1 = w_final*X + b_final
plt.plot(X, y1, '-r', label='y=wx+b')
plt.xlabel("Salinity")
plt.ylabel("Temp degC")
plt.title("Water salinity against temperature")
plt.show()

# %%
# Model performance on the test data
X_test = X[train_size: train_size + (train_size//2)]
y_test = y[train_size: train_size + (train_size//2)]
print(f"Our estimate's cost {compute_cost(X_test, y_test, -0.6, 26)}\n"
      f"Our model's cost {compute_cost(X_test, y_test, w_final, b_final)}")
# Out:
# Our estimate's cost 32.06759449940099
# Our model's cost 7.050583215157285

# %% [markdown]
# ## 2.3 Using Scikit-learn
# Let's compare our attempt against scikit-learn's linear regression

# %%
from sklearn.linear_model import LinearRegression 
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error as mse

# %%
X = X.reshape(-1, 1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.8)

model = LinearRegression()

model.fit(X, y)

w_sk = model.coef_[0]
b_sk = model.intercept_ 

sk_pred = model.predict(X_test)

# %%
our_pred = X_test*w_final + b_final
print(f"The mean squared error of our model: {mse(y_test, our_pred)} vs. Sk_learns: {mse(y_test, sk_pred)}")
# Out:
# The mean squared error of our model: 16.539618606629173 vs. Sk_learns: 13.27792946731726
